# %% [markdown]
# # 第4章: 形態素解析

# %% [markdown]
# 夏目漱石の小説『吾輩は猫である』の文章（[neko.txt](https://nlp100.github.io/data/neko.txt)）をMeCabを使って形態素解析し，その結果をneko.txt.mecabというファイルに保存せよ．このファイルを用いて，以下の問に対応するプログラムを実装せよ．
#
# なお，問題37, 38, 39はmatplotlibもしくはGnuplotを用いるとよい．

# %% [markdown]
# ターミナルで以下を実行
#
# `brew install mecab`
#
# `brew install mecab-ipadic`
#
# `mecab < nlp100knockings2022/neko.txt > nlp100knockings2022/neko.txt.mecab`

# %% [markdown]
# ## 30. 形態素解析結果の読み込み
#
# 形態素解析結果（neko.txt.mecab）を読み込むプログラムを実装せよ．ただし，各形態素は表層形（surface），基本形（base），品詞（pos），品詞細分類1（pos1）をキーとするマッピング型に格納し，1文を形態素（マッピング型）のリストとして表現せよ．第4章の残りの問題では，ここで作ったプログラムを活用せよ．

# %%
#MeCabの公式ページによると、出力フォーマットは以下のようになるとあったので、これを参考にした。
#表層形\t品詞,品詞細分類1,品詞細分類2,品詞細分類3,活用型,活用形,原形,読み,発音

lst = []
with open("neko.txt.mecab") as f:
    text = f.read().split('\n')
    
for line in text:
    if line != "EOS" and line != "":
        tmp = line.split("\t")
        if tmp[0] != "":
            morpheme = tmp[1].split(",")
            lst.append({"surface":tmp[0], "base":morpheme[6], "pos":morpheme[0], "pos1":morpheme[1]})

# %% [markdown]
# ## 31. 動詞
# 動詞の表層形をすべて抽出せよ

# %%
print(", ".join(set(line["surface"] for line in lst if line["pos"] == "動詞")))
# Out:
# ぼ, 吠え, 開け, 沸き上がっ, やろ, ほのめかす, つけ, あらわす, 捕ら, 調子づく, 吹き付ける, 廃する, 案ずる, こたえる, 受け合う, 笑える, どく, 冷える, まくっ, よごれ, 蒙り, 吹き出す, 費やさ, 嘯い, 置き, 入っ, 叩く, 通そ, 暮れれ, 咎めん, 騒ぐ, せら, 取れ, 呼ばわり, 降ら, うなり, わかし, ねじ上げ, ふくれる, 飲め, もったいぶっ, 律すれ, 立ち上っ, 直さ, で, 恋い, ふざけ, 頬張る, 立ち上がっ, 突っ込ん, 乗り出す, 逝い, 固まっ, 進も, 吹く, 飲み, 集まる, あろ, してやる, 引き受け, もとめ, はやる, 縮める, 織り, 息ん, 穿っ, 並ん, 追い廻し, ならべる, 太れる, ととのう, とめ, 挿し, 籠っ, 入れる, 守っ, 改めれ, ゆい, 切り上げよ, 取り出し, やりゃ, 貰い, 落ちつき, 吐き出す, 保つ, 悲しむ, くらし, つくっ, きせ, 行ける, こしらえれ, 得よ, 上げ, 弾き, もぐれ, 解する, 残し, あしらっ, 出会っ, 浮かば, 劣る, 勝た, 弾きゃ, 減る, 変りゃ, とれ, 減れ, しめん, こす, 逆立て, 犯し, 遣わし, ふかす, あやまれ, 愛する, 投げ, 見つめ, 打ち抜い, 吹い, あっ, 洗い, 抛り, あずかり, 登る, 羨む, 貰お, 添う, あか, 焦れ, そろ, 落す, 問い�
, 迷い込ん, 弾こ, 乗り越す, 叩き込み, 論ずる, 申し渡し, 考え出し, 飛び, 書い, すぎ, 叩き上げ, 見立て, 引っ張ら, 当ら, 得, しつくし, 叶え, ならべ, くらす, 擦る, 撲, のしかかる, 合せ, 変ら, したがっ, 来たし, のぼら, 寝ころん, ぱちつかせ, 申し立て, 栄え, 始まる, 彫っ, 飛び出し, 取り扱い, 見せびらかし, 取り去る, 放り出し, 聞きゃ, ふくらまし, 断て, 割り出さ, 済ませ, はち切れる, 追っ, 広げ, 坐, 食べる, 聞かし, 鳴り, 聞き分ける, 起き上がる, 下ら, 償お, 伝える, 説き, 捕る, ゆき, 取り留め, たぎり, 反っ, だし, あるけ, 悟れ, 至っ, あつかう, 受合え, 引込ん, 逆上せん, 参る, 祟っ, 攫ん, 食っ, 見える, 属する, 据わっ, でき, やら, 化け, 分りゃ, 引越す, なやん, つづい, 構い, 断わら, 交ぜ, 鳴か, 志す, 祝う, 蒙る, 埋っ, 来っ, 謡わ, 片づけ, 誘い出し, 蒙っ, かこう, 研ぎ, 盗む, のぼる, こきゃ, ござっ, からん, 落ちる, 剥い, 考え出そ, 申し, 持た, 飛び込む, 投ぜ, 返す, こすり, 起り, 取りあげ, 置か, 誘う, 沿う, うつし, 折り, 損なう, 追い出さ, 解せ, 這入ら, 捻り出し, 召し, 呑ん, 飾り付け, 消そ, 押しつけ, 喰わ, 間に合う, 割い, 描き出し, うく, 圧さ, 行っ ...

# %% [markdown]
# ## 32. 動詞の基本形
#
# 動詞の基本形をすべて抽出せよ．

# %%
print(", ".join(set(line["base"] for line in lst if line["pos"] == "動詞")))
# Out:
# 片づける, ほのめかす, あらわす, 調子づく, 溯る, 吹き付ける, 廃する, 案ずる, こたえる, 受け合う, 笑える, どく, 冷える, つとめる, 吹き出す, 叩く, 騒ぐ, 忍ばす, 称す, ふくれる, 囃す, 戒める, 頬張る, 乗り出す, 見透かす, 追払う, 突き当る, 吹く, 冒す, 集まる, してやる, はやる, 縮める, 数える, 吸取る, 書き付ける, ならべる, 逃げ延びる, 太れる, ととのう, 入れる, すかす, 巡る, 吐き出す, 保つ, 結び付ける, 悲しむ, のせる, 生かす, 合わす, 放り込む, たのむ, 解する, 迷わす, 劣る, 減る, こす, ひそめる, ふくらす, ふかす, 固まる, 愛する, ちょろまかす, 消え失せる, 登る, 畏まる, くだる, 合す, 羨む, 己惚れる, 添う, 落す, 問い掛ける, 舞い戻る, のめる, ひる, 望む, 積み込む, 服せる, 済す, いやがる, あてつける, 傾く, 突き付ける, まする, 裂く, 突っ伏す, さがす, 載っける, くう, 済ませる, 焼ける, ためす, 織る, 考える, 果せる, 断つ, わく, 漂う, 瘠せる, 謡う, 戻す, 曲がる, 捲く, 泊る, 敬う, ぐれる, 嚇す, 引っ掻く, 寄り付く, しだす, 傭う, 飛び上がる, 透かす, 持て余す, づける, 凋む, 使える, 飲み込める, たべる, 舞う, 馴らす, 手伝う, 割り切れる, 恐れ入
, くべる, 招く, 跳ねのける, せる, 残す, うめる, きせる, 蒸す, 食み出す, 追っかける, わける, 交わす, 悟れる, 勤まる, 聞きつける, 整える, 取り出す, 制する, おひゃらかす, 鳴かせる, 営む, 装う, あつまる, 窶す, 転じる, 舞い込む, 照らす, こりる, 任じる, 極め付ける, 差し込む, 飲める, 見つける, くらべる, ごねる, やってくる, 飛込む, 明け放す, 若く, 取りはずす, 云う, 読みかける, 向う, 騰る, のぼせる, いける, 奪い合う, 届け出る, すぼめる, 預る, はじめる, 示す, 触れる, 投げ入れる, 磨く, からむ, 帰る, 打ちつける, 労する, 抱く, 狭める, 重んじる, 合せる, 立ち行く, 坐り込む, 乗り越える, 思い及ぶ, 絶つ, 告げる, おっしゃる, 持てる, 飛びつく, 生きる, 重ねる, 枯れる, だます, 買う, 撲る, 垂れる, 救う, 禁じる, 尋ねる, 捕れる, 願う, 狂わせる, くずす, なれる, 膨らます, いいかねる, 動き出す, 鍛え上げる ...

# %% [markdown]
# ## 33. 「AのB」
#
# 2つの名詞が「の」で連結されている名詞句を抽出せよ．

# %%
ans = set()
for i in range(len(lst)):
    if lst[i-1]["pos"] == "名詞" and lst[i]["surface"] == "の" and \
    lst[i+1]["pos"] == "名詞":
        ans.add(lst[i-1]["surface"] + lst[i]["surface"] + lst[i+1]["surface"])
print(", ".join(ans))
# Out:
# 変物の事, 師匠の所, 珍客の事, 庚申山の麓, 縮緬の紋付, 此等の事, 仙の格言, 熱心の功, 鼻の恐縮, 他の教室, 今日の天気, 万丈の都会, 椽側の前, 化物の犇, もとの野原, 刺激の下, 霊の気, 上の原理, 勺の化学, 以上の感想, 贅沢の結果, 子の言葉, 家の廊下, 茶の味噌, 野中の一軒家, 板の間の上, 館の名誉, 内の老木, 自分の禿頭, 署の管轄, 阿弥の公平, 闔の具合, 婦人の七, 山上の白雲, 虎の鳴き声, おさんの隙, 下手の裁縫, 伯の勝手, 君の様子, 牛込の山伏, 頭の中, 敵の一, いそのビール, 黒の子分, 自信の念, 敵の陣, 無用のもの, 心配の権化, 赤十字の総会, 禅師の電光, 同人の創作, 必然の結果, 自己の何, 家の気, 他の先生, 行水の女, 旗本のよう, 場合のほか, 消極の極, 家の所, 尺寸の手, 人の世, 中学の三, 名刺の影, 勘定のうち, さんの番, 先生の草, 趣味の劇, 元来の骨格, 彼の朦朧, 個の観念, 中心の世, 多量の滋味, 北国の冬空, 唐津の住人, 最中の一つ, 毛布の命, 盛徳の長者, 額の上, 無学の黒, 股の所, 飯櫃の上, 下のよう, 県の生徒, むき出しの棚, 派の俳人, 児の毛, 中の東郷, 談話の方, 先生の所, 厨子の中, 片方の端, 布団の上, 日の事, ペンペン草の目標, 総身の毛穴, だらけの頭, 物思いの間, ベースボールの事, 払底の為, 往来の方, 入口の方, 壁の半ば, ナポレオンのそれ, 方のため, こちらの表, 裏の藪, 胃病の薬, 今代の人, 六の陰気, あとのよう, 顔の前, 床の前, 朝のうち, 茶碗の下, 
��のよう, 這裏の消息, 羽の孔雀, バリー・ペーンの滑稽, 油のよう, 取りの次, 西洋の諺, 表通りの教師, 肝心の目的, 独歩の評論, 絶対の域, 奥の方, 普通の半可通, 冬空のよう, 家の伝, 名前の人間, 椀の底, 椽の下, 猿股の勢力, 裏の車, 注文の声, 私立の中学校, 家々の女, 迷亭の専断, 親子の関係, 僅少のもの, 地上の者, 砲撃の用, 空前の儲け, 耶蘇教の神, 胃のため, ニーチェの時代, 惚の醸造, 漆喰の穴, 目的のとき, 山のなか, 肝心の話, 鼻の構造, 英語のリードル, 観音の像, この間の枝, 君の伯父, こっちの記述, 世の働き, 孑孑のよう, 入りの帽子, 彼の脳裏, 子の顔, 三平のよう, 等の他, 雲母のよう, 山の芋の好き, 何の事, 障子の桟, 男児の本懐, 三平の山の芋, 芝生の上, 吾輩の罪, 寒月の名, 座敷の椽, 何のそれ, 人の気合, 君の逸話, 春の宵, 二つの間, 君の親愛, 掃除のため, 返事の勢, 余りの三, 自分のもの, 君の鼻, 全盛の砌, 堅気の人, 運動の変化, 南側の方面, 自然の傾向, 諸君の名誉, 僕の向う, 竹の真似, 自分の名前, あすの朝, いつの世, 談話の火の手, 沙漠の住民, 赤松の間, 愚劣の考, 場合の適例, あすこの女房, 裏の池, 入りの鋏, 人間の本来, 人の金, 学校の生徒, 初秋の日影, 百の君子, 一掬の涙, 土俵の真中, 無限の感慨, 主人の評判, 日本の墨 ...

# %% [markdown]
# ## 34. 名詞の連接
# 名詞の連接（連続して出現する名詞）を最長一致で抽出せよ

# %%
ans = set()
tmp = []
before = False

for line in lst:
    if line["pos"] == "名詞":
        before = True
        tmp.append(line["surface"])
    elif before:
        if len(tmp) > 1:
            ans.add("".join(tmp))
        tmp = []
        before = False
    
print(", ".join(ans))
# Out:
# 多年苦心研究, 椀底, 七時, 一息つき, 一筋長, 逆上術, 漢名, 諦らめ, あら人, 一箱, 二分, そこかしこ, 新婚学士, 十五六人令嬢, ざる所, 前後相, 肌寒, 忽然豹変, ぐにゃり横, 大変気, 何百遍, 何物たる, 出ずるよう, 蒲原郡筍谷, ちょきちょき, 三度馳, 代り十文半, 豚的幸福, 七時半, 悟りよう, んだい, 一念万年, 十二円五十銭, ゃごおうにゃごおうと三度目, 木板, 三拝, 洗湯界, 往昔羅馬全盛, 探偵的傾向, るいの, 通り手のひら, ——今度東京勤務, 経験譚, 艶味, 一間半, 天然居士噫, 高山彦九郎, コロンバス, 為め熱誠之, 大変味淋, 時聖堂, 一丁目, 鯱鉾町, 人釣白蘋紅蓼間, 米舂, 今日歓迎, 東郷大将, むざと突き, 万遍, 一時非常, きり顔, 人間全体, 大変真面目, なに妙, 野蛮人, 三日月形, 四寸, 慾張り屋, 寒月さん, 一歩向, 一週三度, 先きの, の必要, 男の, マイナス一分刈, 坊ばさん, 秀才水島寒月, 扇使い, 御座候本書, みんな静か, 雪江さん何, 際武右衛門君, 是非共二三十羽, 此発作的活動, めんぼう, なんぼ越
令嬢, 以後注意, 先日玉, 三毛子さん三毛子さん, 一匹, 福地さん, 一手専売, 一つ床, 美学上, 妾等, 風流漢, 校舎新築費, 八分体, 媒酌人たる, 鉱山部, 津軽海峡, 三句, 尻ぺたをひどく, 了見さ, 何これ, 高輪泉岳寺, 後架後架, 正科, 御身分, 六十余字, 乗り廻わし, 一工夫, 局外者, 歌留多会, 横行濶歩, 美学者迷亭先生, あらら, 迷亭一流, 坂本竜馬, 法学士, 書生以外, 自然金田君一家, 果つる, 本人逆, 張合, 世間話, 当該事件, せんだって哲学者, 君一つ譜, 心意的状況, 四五日, 無性猫, 昔人, 托販売, 何者たる, 一軒, 夜十一時頃, 芸術家, 邸内, 二度三度, 一番仕舞, 生憎様, 花活, 平かな顔, 二度, 二三分, 長坂橋, 六十回限り, 蛇飯, 二三尺, 事さ, 外ずし, 仁参, 永年修業, 独創的, ——なに, 論文脱稿前, 帰宅せん間, 二切, かん猪口, ——一丁今, 一部隊, 金色夜叉, 今度限り, 展覧場, 人間自身, 母さま, 帽子屋, 覘い, 次郎ちゃんとこ, 系統内, この間なんざ園遊会, 波斯人, ため道, 十分理解, ——猫なで声, 四五丁, 大分みんな, 普段大事, 寸断寸断, 四六二十四, 二六時中己, みんな鎌倉あたり, 現今英国, 五六日, 大方熊, 四五人下宿, 天明調, 八字, 博士夫人, 夏冬, 六寸三分, 巻煙草入, 大変賞賛, 青年男女, ウェルテル君, 演奏会, 承知さ, 百姓家, 大将隅, 二三度あけ, まま主人, 一生懸命餅, 吾輩猫属, 一番愚, 何だい新体詩, 太さん, あなた真面目, 大分年, 認むるや否や, 樹寂, 舌上, 皆団扇, 希臘語云々, 精神修養, 十年二十年, 砲隊, みんな後ろ, 一点, 呉服屋, 不安心, 妍醜瞭然, 君羅甸語, 嘔吐方, わし一人, せんだってじゅう, 結婚論, 十八世紀, 存候草々不備, 個々別々, 指環, 月々の, 通俗的, 数千年来, なに沢山, 歴史小説, 二口 ...

# %% [markdown]
# ##  35. 単語の出現頻度
# 文章中に出現する単語とその出現頻度を求め，出現頻度の高い順に並べよ．

# %%
import collections

c = collections.Counter([line["surface"] for line in lst if line["pos"] != "記号"])
print(c.most_common())
# Out:
# [('の', 9194), ('て', 6868), ('は', 6420), ('に', 6243), ('を', 6071), ('と', 5508), ('が', 5337), ('た', 3988), ('で', 3806), ('も', 2479), ('ない', 2390), ('だ', 2363), ('し', 2322), ('から', 2032), ('ある', 1728), ('な', 1613), ('ん', 1568), ('か', 1530), ('いる', 1249), ('事', 1207), ('へ', 1034), ('う', 992), ('する', 992), ('もの', 981), ('君', 973), ('です', 973), ('云う', 937), ('主人', 932), ('よう', 696), ('ね', 683), ('この', 649), ('御', 636), ('ば', 617), ('人', 602), ('その', 576), ('一', 554), ('そう', 546), ('何', 539), ('なる', 531), ('さ', 514), ('よ', 509), ('なら', 483), ('吾輩', 481), ('い', 478), ('ます', 458), ('じゃ', 448), ('これ', 414), ('なっ', 404), ('
どうも', 79), ('小', 79), ('さあ', 78), ('話', 77), ('それから', 77), ('得', 76), ('目', 76), ('つけ', 75), ('すれ', 75), ('ましょ', 75), ('まま', 74), ('彼等', 74), ('運動', 74), ('以上', 74), ('仕方', 73), ('もし', 73), ('来る', 73), ('ヴァイオリン', 73), ('もん', 73), ('全く', 73), ('あろ', 72), ('のみ', 72), ('つい', 72), ('つもり', 72), ('内', 71), ('物', 71), ('だい', 71), ('名', 71), ('早く', 71), ('何だか', 70), ('決して', 70), ('のに', 70), ('見える', 70), ('ほか', 68), ('それで', 68), ('出る', 68), ('音', 67), ('かく', 67), ('右', 67), ('思わ', 66), ('なんか', 66), ('様', 66), ('あと', 65), ('べき', 65), ('這入っ', 65), ('寝', 65), ('入れ', 65), ('大分', 65), ('そんなに', 65), ('す', 65), ('八', 65), ('教師', 64), ('食っ', 64), ('みんな', 64), ('たく', 63), ('必ず', 63), ('あら', 63), ('おい', 63), ('相違', 63), ('心配', 63), ('毛', 62), ('無', 62), ('急', 62), ('いつ', 62), ('ところが', 62), ('黒', 62), ('だから', 62), ('先', 61), ('行か', 61), ('そりゃ', 61), ('なさい', 61), ('思い', 60), ('すると', 60), ('書斎', 60), ('候', 60), ('ら', 60), ('敵', 60), ('同じ', 59), ('まず', 59), ('事件', 59), ('はず', 58), ('足', 58), ('始め', 57), ('知っ', 57), ('供', 57), ('いえ', 57), ('において', 57), ('なに', 57), ('り', 56), (' ...

# %% [markdown]
# ##  36. 頻度上位10語
# 出現頻度が高い10語とその出現頻度をグラフ（例えば棒グラフなど）で表示せよ．

# %%
import matplotlib.pyplot as plt
import japanize_matplotlib

target = list(zip(*c.most_common(10)))
plt.bar(*target)
plt.show()

# %% [markdown]
# ##  37. 「猫」と共起頻度の高い上位10語
#
# 「猫」とよく共起する（共起頻度が高い）10語とその出現頻度をグラフ（例えば棒グラフなど）で表示せよ．

# %%
#共起回数　＝　「猫」が同じ文に現れる回数

tmp_cooccurrence = []
cooccurrence = []
isinCat = False

for line in lst:
    if line["surface"] == "。":
        if isinCat:
            cooccurrence.extend(tmp)
        tmp = []
        inCat = False
    else:
        if line["surface"] == "猫":
            isinCat = True
        elif line["pos"] != "記号":
            tmp.append(line["surface"])

c = collections.Counter(cooccurrence)
target = list(zip(*c.most_common(10)))
plt.bar(*target)
plt.show()

# %% [markdown]
# ## 38. ヒストグラム
# 単語の出現頻度のヒストグラムを描け．ただし，横軸は出現頻度を表し，1から単語の出現頻度の最大値までの線形目盛とする．縦軸はx軸で示される出現頻度となった単語の異なり数（種類数）である．

# %%
c = collections.Counter([line["surface"] for line in lst])
plt.figure(figsize=(8, 4))
plt.hist(c.values(), bins=100)
plt.show()

# %% [markdown]
# ##  39. Zipfの法則
#
# 単語の出現頻度順位を横軸，その出現頻度を縦軸として，両対数グラフをプロットせよ．

# %%
plt.figure(figsize=(8, 4))
plt.scatter(list(range(len(c))), [count for _, count in c.most_common()])
plt.xscale('log')
plt.yscale('log')
